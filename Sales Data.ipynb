# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales=pd.read_csv('salesdata.csv')

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description item_price
# 0                                         [Clementine]     $3.39
# 1                                              [Apple]     $3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %%
sales.describe()
# Out:
#          order_id    quantity
# count  200.000000  200.000000
# mean    62.025000    1.060000
# std     34.527163    0.238083
# min      1.000000    1.000000
# 25%     30.750000    1.000000
# 50%     64.500000    1.000000
# 75%     92.250000    1.000000
# max    119.000000    2.000000

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            200 non-null    int64
#  1   quantity            200 non-null    int64
#  2   item_name           200 non-null    object
#  3   choice_description  200 non-null    object
#  4   item_price          200 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 7.9+ KB

# %%
sales.head()
# Out:
#    order_id  quantity         item_name  \
# 0         1         1              Izze
# 1         1         1  Nantucket Nectar
# 2         2         2      Chicken Bowl
# 3         3         1      Chicken Bowl
# 4         4         1     Steak Burrito
#
#                                   choice_description item_price
# 0                                       [Clementine]     $3.39
# 1                                            [Apple]     $3.39
# 2  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 3  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 4  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75

# %%
sales.tail()
# Out:
#      order_id  quantity            item_name  \
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description item_price
# 195  [Roasted Chili Corn Salsa (Medium), [Black Bea...     $8.99
# 196      [Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]     $9.25
# 197  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...     $8.99
# 198  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 199  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...     $8.49

# %%
sales['item_price']= sales['item_price'].str.replace('[/$/.]', '').astype(int)
# Out:
# /var/folders/ps/2vlq2m8s1wj_1_lqthwm97dw0000gn/T/ipykernel_15413/3407242252.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   sales['item_price']= sales['item_price'].str.replace('[/$/.]', '').astype(int)

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]         339
# 1                                              [Apple]         339
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...        1698
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...        1098
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        1175
# ...

# %%
sales['item_price']=sales['item_price']/100

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]        3.39
# 1                                              [Apple]        3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
#amount of products that cost more than $10
len(sales[sales['item_price'] > 10])
# Out:
# 60

# %%
#visualization of the products that cost more than $10
greater=sales[sales['item_price']>10]
greater
# Out:
#      order_id  quantity              item_name  \
# 2           2         2           Chicken Bowl
# 3           3         1           Chicken Bowl
# 4           4         1          Steak Burrito
# 9           7         1           Chicken Bowl
# 16         12         1        Chicken Burrito
# 26         19         1          Barbacoa Bowl
# 27         20         1           Chicken Bowl
# 28         20         1          Steak Burrito
# 30         21         1        Chicken Burrito
# 36         24         1        Chicken Burrito
# 40         26         1         Veggie Burrito
# 41         27         1          Barbacoa Bowl
# 43         28         1            Veggie Bowl
# 49         30         1        Chicken Burrito
# 56         35         1     Chicken Soft Tacos
# 64         40         1             Steak Bowl
# 65         40         1             Steak Bowl
# 67         41         1       Carnitas Burrito
# 69         43         1          Carnitas Bowl
# ...

# %%
sns.set_style('darkgrid')
fig,ax =plt.subplots(figsize=(30,30))
sns.barplot(y=greater['item_name'], x=greater['item_price']);
ax.set(xlabel='NAMES OF ITEMS', ylabel='PRICES($)');

# %%
len(sales[sales['item_price']<10])
# Out:
# 140

# %%
#products that cost less than $10
lesser=sales[sales['item_price']<10]
lesser
# Out:
#      order_id  quantity             item_name  \
# 0           1         1                  Izze
# 1           1         1      Nantucket Nectar
# 5           4         1      Steak Soft Tacos
# 6           5         1         Steak Burrito
# 7           6         1  Chicken Crispy Tacos
# ..        ...       ...                   ...
# 195       115         1         Steak Burrito
# 196       116         1      Steak Soft Tacos
# 197       117         1   Barbacoa Soft Tacos
# 198       118         1       Chicken Burrito
# 199       119         1       Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]        3.39
# 1                                              [Apple]        3.39
# 5    [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...        9.25
# 6    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 7    [Roasted Chili Corn Salsa, [Fajita Vegetables,...        8.75
# ...

# %%
sales['item_name'].unique()
# Out:
# array(['Izze', 'Nantucket Nectar', 'Chicken Bowl', 'Steak Burrito',
#        'Steak Soft Tacos', 'Chicken Crispy Tacos', 'Chicken Soft Tacos',
#        'Chicken Burrito', 'Canned Soda', 'Barbacoa Burrito',
#        'Carnitas Burrito', 'Carnitas Bowl', 'Barbacoa Bowl',
#        'Chicken Salad Bowl', 'Steak Bowl', 'Barbacoa Soft Tacos',
#        'Veggie Burrito', 'Veggie Bowl', 'Steak Crispy Tacos',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Carnitas Soft Tacos', 'Chicken Salad', 'Canned Soft Drink'],
#       dtype=object)

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]        3.39
# 1                                              [Apple]        3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
items=sales['item_name']
items
# Out:
# 0                     Izze
# 1         Nantucket Nectar
# 2             Chicken Bowl
# 3             Chicken Bowl
# 4            Steak Burrito
#               ...
# 195          Steak Burrito
# 196       Steak Soft Tacos
# 197    Barbacoa Soft Tacos
# 198        Chicken Burrito
# 199        Chicken Burrito
# Name: item_name, Length: 200, dtype: object

# %%
prices=sales['item_price']
prices
# Out:
# 0       3.39
# 1       3.39
# 2      16.98
# 3      10.98
# 4      11.75
#        ...
# 195     8.99
# 196     9.25
# 197     8.99
# 198     8.49
# 199     8.49
# Name: item_price, Length: 200, dtype: float64

# %%
import pandas as pd

# %%
#price of each items
First=sales[['item_name','item_price']]
First
# Out:
#                item_name  item_price
# 0                   Izze        3.39
# 1       Nantucket Nectar        3.39
# 2           Chicken Bowl       16.98
# 3           Chicken Bowl       10.98
# 4          Steak Burrito       11.75
# ..                   ...         ...
# 195        Steak Burrito        8.99
# 196     Steak Soft Tacos        9.25
# 197  Barbacoa Soft Tacos        8.99
# 198      Chicken Burrito        8.49
# 199      Chicken Burrito        8.49
#
# [200 rows x 2 columns]

# %%
#sorting products by name of items
sales.sort_values(by=['item_name'])
# Out:
#      order_id  quantity          item_name  \
# 41         27         1      Barbacoa Bowl
# 95         61         1      Barbacoa Bowl
# 90         56         1      Barbacoa Bowl
# 26         19         1      Barbacoa Bowl
# 185       110         1      Barbacoa Bowl
# ..        ...       ...                ...
# 184       110         1        Veggie Bowl
# 162        99         1     Veggie Burrito
# 40         26         1     Veggie Burrito
# 74         46         1     Veggie Burrito
# 132        83         1  Veggie Salad Bowl
#
#                                     choice_description  item_price
# 41   [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.75
# 95   [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 90   [Tomatillo Red Chili Salsa, [Rice, Pinto Beans...        9.25
# 26   [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.75
# 185  [Tomatillo Red Chili Salsa, [Rice, Cheese, Let...        9.25
# ...

# %%
sales.sort_values(by=['item_price'])
# Out:
#      order_id  quantity             item_name  \
# 143        89         1           Canned Soda
# 20         14         1           Canned Soda
# 89         55         1           Canned Soda
# 139        87         1           Canned Soda
# 37         24         1           Canned Soda
# ..        ...       ...                   ...
# 172       105         2       Chicken Burrito
# 156        96         2  Chicken Crispy Tacos
# 103        67         2         Steak Burrito
# 94         60         2    Chicken Salad Bowl
# 153        94         2    Chicken Salad Bowl
#
#                                     choice_description  item_price
# 143                                        [Diet Coke]        1.09
# 20                                        [Dr. Pepper]        1.09
# 89                                         [Coca Cola]        1.09
# 139                                        [Coca Cola]        1.09
# 37                                            [Sprite]        1.09
# ...

# %%
expensive=sales[['quantity','item_name','item_price']]
expensive
# Out:
#      quantity            item_name  item_price
# 0           1                 Izze        3.39
# 1           1     Nantucket Nectar        3.39
# 2           2         Chicken Bowl       16.98
# 3           1         Chicken Bowl       10.98
# 4           1        Steak Burrito       11.75
# ..        ...                  ...         ...
# 195         1        Steak Burrito        8.99
# 196         1     Steak Soft Tacos        9.25
# 197         1  Barbacoa Soft Tacos        8.99
# 198         1      Chicken Burrito        8.49
# 199         1      Chicken Burrito        8.49
#
# [200 rows x 3 columns]

# %%
#quantity of the most expensive item ordered
expensive.sort_values(by=['item_price']).tail()
# Out:
#      quantity             item_name  item_price
# 172         2       Chicken Burrito       17.50
# 156         2  Chicken Crispy Tacos       17.50
# 103         2         Steak Burrito       17.98
# 94          2    Chicken Salad Bowl       22.50
# 153         2    Chicken Salad Bowl       22.50

# %%
more=expensive.sort_values(by=['item_price']).tail(2)
more
# Out:
#      quantity           item_name  item_price
# 94          2  Chicken Salad Bowl        22.5
# 153         2  Chicken Salad Bowl        22.5

# %%
sales
# Out:
#      order_id  quantity            item_name  \
# 0           1         1                 Izze
# 1           1         1     Nantucket Nectar
# 2           2         2         Chicken Bowl
# 3           3         1         Chicken Bowl
# 4           4         1        Steak Burrito
# ..        ...       ...                  ...
# 195       115         1        Steak Burrito
# 196       116         1     Steak Soft Tacos
# 197       117         1  Barbacoa Soft Tacos
# 198       118         1      Chicken Burrito
# 199       119         1      Chicken Burrito
#
#                                     choice_description  item_price
# 0                                         [Clementine]        3.39
# 1                                              [Apple]        3.39
# 2    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 3    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4    [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
#how many times was a chicken burrito ordered
chicken_burrito=sales[sales['item_name']=="Chicken Burrito"]
chicken_burrito
# Out:
#      order_id  quantity        item_name  \
# 10          8         1  Chicken Burrito
# 11          9         1  Chicken Burrito
# 16         12         1  Chicken Burrito
# 21         15         1  Chicken Burrito
# 30         21         1  Chicken Burrito
# 36         24         1  Chicken Burrito
# 44         28         1  Chicken Burrito
# 49         30         1  Chicken Burrito
# 52         33         1  Chicken Burrito
# 58         36         1  Chicken Burrito
# 59         37         1  Chicken Burrito
# 70         43         1  Chicken Burrito
# 80         50         1  Chicken Burrito
# 82         51         1  Chicken Burrito
# 85         53         1  Chicken Burrito
# 92         58         1  Chicken Burrito
# 93         59         1  Chicken Burrito
# 104        68         2  Chicken Burrito
# 105        69         1  Chicken Burrito
# 109        72         1  Chicken Burrito
# 111        73         1  Chicken Burrito
# 115        75         1  Chicken Burrito
# ...

# %%
len(chicken_burrito)
# Out:
# 39

# %%
#how many times did someone order more than one canned soda
canned_soda=sales[sales['item_name']=='Canned Soda']
canned_soda
# Out:
#      order_id  quantity    item_name choice_description  item_price
# 12          9         2  Canned Soda           [Sprite]        2.18
# 20         14         1  Canned Soda       [Dr. Pepper]        1.09
# 35         23         2  Canned Soda     [Mountain Dew]        2.18
# 37         24         1  Canned Soda           [Sprite]        1.09
# 77         47         1  Canned Soda       [Dr. Pepper]        1.09
# 83         51         1  Canned Soda  [Diet Dr. Pepper]        1.09
# 89         55         1  Canned Soda        [Coca Cola]        1.09
# 112        73         2  Canned Soda        [Diet Coke]        2.18
# 119        76         2  Canned Soda  [Diet Dr. Pepper]        2.18
# 127        81         1  Canned Soda        [Coca Cola]        1.09
# 128        81         1  Canned Soda       [Dr. Pepper]        1.09
# 139        87         1  Canned Soda        [Coca Cola]        1.09
# 143        89         1  Canned Soda        [Diet Coke]        1.09
# ...

# %%
canned_soda_amount=canned_soda[canned_soda['quantity']>1]
canned_soda_amount
# Out:
#      order_id  quantity    item_name choice_description  item_price
# 12          9         2  Canned Soda           [Sprite]        2.18
# 35         23         2  Canned Soda     [Mountain Dew]        2.18
# 112        73         2  Canned Soda        [Diet Coke]        2.18
# 119        76         2  Canned Soda  [Diet Dr. Pepper]        2.18

# %%
len(canned_soda_amount)
# Out:
# 4

# %%
fig,ax = plt.subplots(figsize = (20,6))
ax.hist(sales['item_name'], bins=100, width=0.4, color='blue');
ax.set(title='Amount of times a Product was Ordered',
      xlabel='Item Name',
      ylabel='Orders')
plt.tick_params(axis='both', which='major', labelsize=5 )
fig.suptitle('VISUALIZATION',fontweight='bold', fontsize=16);
